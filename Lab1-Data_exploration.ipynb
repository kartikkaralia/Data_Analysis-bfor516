# %% [markdown]
# # Lab 1 - Data Exploration
# We will use the provided weather data to plot the mean temperature for each month in the dataset. To achieve the goal, `pandas` library would be used.

# %% [markdown]
# **Python Libraries**
#
# First we will import the python libraries, pandas (a data management package) and datetime (a package to format dates).

# %%
import pandas as pd
import datetime

# %% [markdown]
# **Import Data**

# %%
# read file
weather = pd.read_csv('last_ten_alb.csv')

# %% [markdown]
# **View Data**
#
# Using the .head() function from pandas, we can see the first 5 rows of the dataframe.

# %%
# print first 5 rows
weather.head()
# Out:
#    Unnamed: 0   timestamp   mean_tmp  mean_tmp_f  dew_point  dew_point_f  \
# 0           0  2012-01-01   5.333333          24       36.0           24
# 1           1  2012-01-02   3.722222          24       27.4           24
# 2           2  2012-01-03  -5.888889          24        9.3           24
# 3           3  2012-01-04 -11.777778          24       -1.1           24
# 4           4  2012-01-05  -3.833333          24       12.8           24
#
#    mean_sea_level_press  mean_sea_level_press_f  mean_stn_pressure  \
# 0                1013.5                      22             1003.5
# 1                1003.9                      23              992.9
# 2                1012.5                      24             1001.0
# 3                1020.8                      24             1009.5
# 4                1012.2                      22             1001.0
#
#    mean_stn_pressure_f  ...  tornado_f    station_id  ctry  state  \
# ...

# %% [markdown]
# **Convert Dates**
#
# Currently the dates are stored as strings, and we need to convert them to datetime format for further processing. For this, we will use the to_datetime() function.

# %%
# convert dates
weather['timestamp']=pd.to_datetime(weather['timestamp'])

# %% [markdown]
# **Data about each Column**
#
# To see details about each column, we will use the describe() function

# %%
# column details
weather.describe(include='all', datetime_is_numeric=True)
# Out:
#          Unnamed: 0                      timestamp     mean_tmp   mean_tmp_f  \
# count   3888.000000                           3888  3888.000000  3888.000000
# unique          NaN                            NaN          NaN          NaN
# top             NaN                            NaN          NaN          NaN
# freq            NaN                            NaN          NaN          NaN
# mean     178.212449  2017-04-27 12:00:00.000000256    10.148448    23.995628
# min        0.000000            2012-01-01 00:00:00   -20.444444     7.000000
# 25%       88.000000            2014-08-29 18:00:00     1.722222    24.000000
# 50%      176.000000            2017-04-27 12:00:00    10.777778    24.000000
# 75%      268.000000            2019-12-25 06:00:00    19.611111    24.000000
# max      365.000000            2022-08-23 00:00:00    31.111111    24.000000
# std      104.738930                            NaN    10.505663     0.272638
#
# ...

# %% [markdown]
# **Average Temperature**
#
# To get the average temperature, we can use the Grouper() function.

# %%
# grouping by year
annual_avg_temp = weather.groupby(pd.Grouper(key='timestamp', freq='Y')).mean()
annual_avg_temp
# Out:
#             Unnamed: 0   mean_tmp  mean_tmp_f  dew_point  dew_point_f  \
# timestamp
# 2012-12-31       182.5  11.024894    24.00000  40.507377     24.00000
# 2013-12-31       182.0   9.508067    24.00000  37.835616     24.00000
# 2014-12-31       182.0   9.187367    24.00000  36.442466     24.00000
# 2015-12-31       182.0   9.997717    24.00000  36.967945     24.00000
# 2016-12-31       182.5  10.727838    24.00000  38.268579     24.00000
# 2017-12-31       182.0  10.274581    24.00000  38.684384     24.00000
# 2018-12-31       182.0  10.298630    24.00000  38.700274     24.00000
# 2019-12-31       182.0   9.912938    24.00000  37.187123     24.00000
# 2020-12-31       182.5  10.487098    24.00000  39.172951     24.00000
# 2021-12-31       182.0   9.561492    24.00000  40.458082     23.99726
# 2022-12-31       117.0  10.923404    23.92766  37.816596     23.92766
#
#             mean_sea_level_press  mean_sea_level_press_f  mean_stn_pressure  \
# timestamp
# ...

# %% [markdown]
# Mean of monthly temperature can also be calculated by changing frequency period.

# %%
monthly_avg_temp = weather.groupby(pd.Grouper(key='timestamp', freq='M')).mean()
monthly_avg_temp
# Out:
#             Unnamed: 0   mean_tmp  mean_tmp_f  dew_point  dew_point_f  \
# timestamp
# 2012-01-31        15.0  -1.749104    24.00000  19.416129     24.00000
# 2012-02-29        45.0   0.342912    24.00000  21.172414     24.00000
# 2012-03-31        75.0   7.664875    24.00000  31.103226     24.00000
# 2012-04-30       105.5   9.187037    24.00000  30.946667     24.00000
# 2012-05-31       136.0  17.288530    24.00000  51.712903     24.00000
# ...                ...        ...         ...        ...          ...
# 2022-04-30       104.5   9.020370    24.00000  31.463333     24.00000
# 2022-05-31       135.0  17.523297    24.00000  47.422581     24.00000
# 2022-06-30       165.5  20.157407    24.00000  53.106667     24.00000
# 2022-07-31       196.0  24.401434    24.00000  59.677419     24.00000
# 2022-08-31       223.0  23.949275    23.26087  61.660870     23.26087
#
#             mean_sea_level_press  mean_sea_level_press_f  mean_stn_pressure  \
# timestamp
# ...

# %% [markdown]
# **Mean Temperature of each month**
#
# Although, we got the Average monthly temperatures, but they are on a daily basis. So, we need to group up data as monthly and then calculate the average.

# %%
# group by month rater than intervals
monthwise_avg_temp = weather.groupby(weather['timestamp'].dt.month).mean()
monthwise_avg_temp
# Out:
#            Unnamed: 0   mean_tmp  mean_tmp_f  dew_point  dew_point_f  \
# timestamp
# 1           15.000000  -3.623493   24.000000  15.149560    24.000000
# 2           44.639871  -2.300286   24.000000  16.548553    24.000000
# 3           74.272727   2.363311   24.000000  21.694428    24.000000
# 4          104.772727   8.681650   24.000000  31.190000    24.000000
# 5          135.272727  16.043174   24.000000  46.118768    24.000000
# 6          165.772727  20.226768   24.000000  54.923333    24.000000
# 7          196.272727  23.253014   24.000000  61.662170    24.000000
# 8          227.003003  21.917918   23.948949  60.870270    23.948949
# 9          257.800000  17.793704   24.000000  54.430333    23.996667
# 10         288.300000  11.861470   24.000000  44.213226    24.000000
# 11         318.800000   4.263148   24.000000  29.097000    24.000000
# 12         349.300000   0.224910   24.000000  23.650645    24.000000
#
# ...

# %% [markdown]
# **Plotting the graph**
#
# Data in a visual form is easy to read, understand and interpret from. So, we will plot a graph here for the month-wise average temperature. And for this purpose, we will use .plot() function.

# %%
monthwise_avg_temp['mean_tmp'].plot(xlabel='Month', ylabel='Temp (in C)', title="Month-wise Avg Temp", )
# Out:
# <AxesSubplot:title={'center':'Month-wise Avg Temp'}, xlabel='Month', ylabel='Temp (in C)'>

# %% [markdown]
# **Unnamed: 0**
